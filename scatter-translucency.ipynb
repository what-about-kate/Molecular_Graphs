# %%
# %matplotlib inline

import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
name = 'er-lit'
x = []
with open("er_lit-Wiener_indices.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        arr = [float(i) for i in row]
        x.append(np.sqrt(arr[0]))
        
#print (x)
print (len(x))
# Out:
# 393

# %%
y = []
with open("er_lit-Randich_indices.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        arr = [float(i) for i in row]
        y.append(arr[0])
        
#print (y)
print (len(y))
# Out:
# 393

# %%
xx = []
yy = []

for i in range(len(x)) :
    if x[i] >= 12 and x[i] <= 50 :
        xx.append(x[i])
        yy.append(y[i])

# %%
fig, ax = plt.subplots()

color = (0.5, 0.2, 0.3, 0.4)

ax.scatter(x, y, c=color)

ax.set_facecolor('white')
ax.set_title(name, fontsize=20, color='black')

ax.set_xlabel("sqrt (Wiener index)", fontsize=15, color='black', labelpad=10)
ax.set_ylabel("Randich index", fontsize=15, color='black', labelpad=10)

fig.set_figwidth(20)
fig.set_figheight(10)

plt.show()

#fig.savefig(name)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
fig, ax = plt.subplots()

ax.scatter(xx, yy, c='green')

ax.set_facecolor('white')
ax.set_title(name, fontsize=20, color='black')

ax.set_xlabel("sqrt (Wiener index)", fontsize=15, color='black', labelpad=10)
ax.set_ylabel("Randich index", fontsize=15, color='black', labelpad=10)

fig.set_figwidth(20)
fig.set_figheight(10)

plt.show()

str = name + '_1'
fig.savefig(str)

# %%
#https://pyprog.pro/mpl/mpl_scatter.html

# %% [markdown]
# ![image.png](attachment:image.png)
